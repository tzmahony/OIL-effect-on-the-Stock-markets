# %%
import pandas as pd

# %%
#load the data
from google.colab import files 
upload = files.upload()
# Out:
#      <input type="file" id="files-c6c4f504-bed6-4a7a-ae1c-4b450d100b83" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6c4f504-bed6-4a7a-ae1c-4b450d100b83">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving PFE(1).csv to PFE(1).csv

# %% [markdown]
# df = pd.read_csv('NKE.csv')
# df.head(6)

# %%
df = pd.read_csv('PFE(1).csv')
df.head(-6)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     20/05/1987   2.436156   2.460863   2.411448   2.436156   0.812889
# 1     21/05/1987   2.455922   2.485571   2.446039   2.465805   0.822782
# 2     22/05/1987   2.490512   2.515220   2.465805   2.490512   0.831025
# 3     26/05/1987   2.510278   2.574518   2.495454   2.569576   0.857408
# 4     27/05/1987   2.559693   2.574518   2.539927   2.564635   0.855759
# ...          ...        ...        ...        ...        ...        ...
# 7866  03/08/2018  37.590134  38.576851  37.466793  38.462997  33.615662
# 7867  06/08/2018  38.292221  39.108158  38.263756  38.937382  34.030266
# 7868  07/08/2018  38.757114  39.136623  38.700191  38.747627  33.864422
# 7869  08/08/2018  38.624287  39.506641  38.500950  39.288425  34.337067
# 7870  09/08/2018  39.184059  39.250473  38.719166  38.899429  33.997089
#
#           Volume  Price  crude price
# 0     17193691.0  18.63        19.75
# ...

# %%
print(df.describe())
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  7876.000000  7876.000000  7876.000000  7876.000000  7876.000000
# mean     20.609106    20.828098    20.381565    20.608250    11.841218
# std      12.288124    12.428050    12.139478    12.287456     8.145435
# min       1.645517     1.665283     1.630693     1.645517     0.557738
# 25%       6.587009     6.658661     6.527711     6.601834     2.775393
# 50%      22.630059    22.817837    22.419355    22.628082    12.388912
# 75%      31.062618    31.359107    30.740038    31.034157    17.137630
# max      47.181374    47.477863    46.331436    47.477863    34.345356
#
#              Volume        Price  crude price
# count  7.876000e+03  7877.000000  7877.000000
# mean   2.422402e+07    45.401162    44.717358
# std    2.067725e+07    33.049384    29.667500
# min    5.337460e+05     9.100000    10.820000
# 25%    1.028409e+07    18.600000    19.950000
# 50%    1.798756e+07    29.440000    31.080000
# ...

# %%
# Reindex data using a DatetimeIndex
df.set_index(pd.DatetimeIndex(df['Date']), inplace=True)

# Keep only the 'Adj Close' Value
df = df[['Adj Close']]

# Re-inspect data
print(df)

# Print Info
print(df.info())
# Out:
#             Adj Close
# Date
# 1987-05-20   0.812889
# 1987-05-21   0.822782
# 1987-05-22   0.831025
# 1987-05-26   0.857408
# 1987-05-27   0.855759
# ...               ...
# 2018-08-13  33.839546
# 2018-08-14  33.756622
# 2018-08-15  34.129761
# 2018-08-16  34.345356
# NaT               NaN
#
# [7877 rows x 1 columns]
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7877 entries, 1987-05-20 to NaT
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  7876 non-null   float64
# dtypes: float64(1)
# memory usage: 123.1 KB
# None

# %%
df = pd.read_csv('PFE(1).csv')

# %%
import matplotlib.pyplot as plt

# %%
# # Drop the first n-rows
# df = df.iloc[10:]
# # View our newly-formed dataset
# print(df.head(10))

# %%
print(df.head(10))
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume  \
# 0  20/05/1987  2.436156  2.460863  2.411448  2.436156   0.812889  17193691.0
# 1  21/05/1987  2.455922  2.485571  2.446039  2.465805   0.822782  12174965.0
# 2  22/05/1987  2.490512  2.515220  2.465805  2.490512   0.831025  10525666.0
# 3  26/05/1987  2.510278  2.574518  2.495454  2.569576   0.857408  11069530.0
# 4  27/05/1987  2.559693  2.574518  2.539927  2.564635   0.855759   7576152.0
# 5  28/05/1987  2.559693  2.589342  2.510278  2.579459   0.860705  10335946.0
# 6  29/05/1987  2.594284  2.604167  2.559693  2.574518   0.859056   8309736.0
# 7  01/06/1987  2.594284  2.594284  2.559693  2.579459   0.860705   9344342.0
# 8  02/06/1987  2.569576  2.594284  2.549810  2.594284   0.865652   8355269.0
# 9  03/06/1987  2.604167  2.698055  2.604167  2.698055   0.900277  16047782.0
#
#    Price  crude price
# 0  18.63        19.75
# 1  18.45        19.95
# 2  18.55        19.68
# 3  18.60        19.35
# ...

# %%
#visualise the close price data
plt.figure(figsize=(16,8))
plt.title('Pfizer prices(Blue), Brent price(Orange), Crude price (Green) ')
plt.xlabel('Date')
plt.ylabel('closing price USD($)')
plt.plot(df['Open'])
plt.plot(df['Price'])
plt.plot(df['crude price'])
plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# Split data into testing and training sets
X_train, X_test, y_train, y_test = train_test_split(df[['Close']], df[['Price']], test_size=.2)
print(X_test.describe())
# Out:
#              Close
# count  1576.000000
# mean      7.237735
# std      11.440751
# min       0.116629
# 25%       0.351563
# 50%       0.565011
# 75%       9.560268
# max      51.777500

# %%
print(X_train.describe())
# Out:
#              Close
# count  6300.000000
# mean      7.418292
# std      11.647722
# min       0.115513
# 25%       0.349330
# 50%       0.541629
# 75%      11.018035
# max      53.330002

# %%
X_train.head
# Out:
# <bound method NDFrame.head of           Close
# 5815   9.053929
# 4280   0.474643
# 4460   1.263571
# 6907  24.952499
# 5739   7.037857
# ...         ...
# 1021   0.438616
# 1187   0.564732
# 5817   9.274643
# 5221   4.776786
# 6627  17.449286
#
# [6301 rows x 1 columns]>

# %%
y_train.head
# Out:
# <bound method NDFrame.head of        Price
# 5815   84.49
# 4280   34.40
# 4460   44.23
# 6907  101.68
# 5739   71.33
# ...      ...
# 1021   18.75
# 1187   17.18
# 5817   82.77
# 5221   95.33
# 6627  107.46
#
# [6301 rows x 1 columns]>

# %%
from sklearn.linear_model import LinearRegression

# Create Regression Model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Use model to make predictions
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-03914d39f1a5> in <module>()
#       5
#       6 # Train the model
# ----> 7 model.fit(X_train, y_train)
#       8
#       9 # Use model to make predictions
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     661
#     662         X, y = self._validate_data(
# --> 663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#     665
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
# Printout relevant metrics
print("Model Coefficients:", model.coef_)
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Coefficient of Determination:", r2_score(y_test, y_pred))

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,8))
plt.title('Nike prices')
plt.xlabel('Close')
plt.ylabel('Price')
# plt.plot(model.coef_)
# plt.plot([mean_absolute_error(y_test, y_pred)])
# plt.plot([r2_score(y_test, y_pred)])
model = LinearRegression(fit_intercept=True)

model.fit(x[:, np.newaxis], y)

xfit = np.linspace(0, 10, 1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit);

plt.plot(X_train.value, y_pred.value)
plt.show()
